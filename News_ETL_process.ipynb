# %% [markdown]
# <a href="https://colab.research.google.com/github/fvgm-spec/learn-airbyte/blob/main/News_ETL_process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Traditional ETL process
#
#  The following is a traditional ETL process, which is based on batch data processing coming from API calls to [News API](https://newsapi.org/). The Data is collected and processed in predefined blocks as Python functions.

# %% [markdown]
# ### Step 1: Importing required packages and setting global variables

# %%
import pandas as pd
import json
import requests

# %%
url = 'https://newsapi.org/v2/everything'
from google.colab import userdata
api_key = userdata.get('NEWS_API_KEY')

# %% [markdown]
# ### Step 2: Defining functions

# %%
#Defines a function to extract data from API endpoint
def api_data_extraction(api_endpoint: str, query: str, api_key: str):
    """
    Extracts data from an API endpoint

    Args:
        api_endpoint (str): name of the endpoint from the config.ini file.
        query (str): the search term or specific data to retrieve from API call.
        api_key (str): the API key required for authorization.
    Returns:
        dict: The JSON data extracted from the API call.
    """
    ##Extracting data from API
    r = requests.get(f"{api_endpoint}?q={query}&from=2024-03-21"
                     f"&sortBy=publishedAt&apiKey={api_key}")

    return r.json()

#Defines a function to transform JSON data into a pandas DataFrame
def data_transformation(json_data: dict) -> pd.DataFrame:
    """
    Converts the JSON data extracted from API call into a pandas DataFrame

    Args:
        json_data (dict): the data extracted from the API endpoint.
    Returns:
        pd.DataFrame: DataFrame containing the flattened data from the data in JSON format.
    """
    # Access the 'articles' list within the main dictionary
    articles = json_data['articles']

    # Create a list to store dictionaries with flattened data
    flat_data = []

    # Iterate through each article dictionary
    for article in articles:
        # Create a dictionary to store flattened key-value pairs
        article_data = {}

        # Access and store relevant information from the nested dictionary
        article_data['source_name'] = article['source']['name']
        article_data['author'] = article.get('author')
        article_data['title'] = article['title']
        article_data['description'] = article.get('description')
        article_data['url'] = article['url']
        article_data['urlToImage'] = article.get('urlToImage')
        article_data['publishedAt'] = article['publishedAt']

        # Append the flattened dictionary to the list
        flat_data.append(article_data)

    # Create a DataFrame from the list of dictionaries
    df = pd.DataFrame(flat_data)

    return df

# %% [markdown]
# ### Step 3: Using helper functions to extract data from API endpoints and then performing data transformations

# %%
data = api_data_extraction(url,"eclipse",api_key)

# %%
df = data_transformation(data)

# %%
# Transforming data extracted from API
df['publishedAt'] = pd.to_datetime(df['publishedAt'], utc=True)

# Create new columns for year, month, day
df['year'] = df['publishedAt'].dt.year
df['month'] = df['publishedAt'].dt.month_name()  # Month name as string
df['day'] = df['publishedAt'].dt.day

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   source_name  100 non-null    object
#  1   author       90 non-null     object
#  2   title        100 non-null    object
#  3   description  99 non-null     object
#  4   url          100 non-null    object
#  5   urlToImage   84 non-null     object
#  6   publishedAt  100 non-null    datetime64[ns, UTC]
#  7   year         100 non-null    int32
#  8   month        100 non-null    object
#  9   day          100 non-null    int32
# dtypes: datetime64[ns, UTC](1), int32(2), object(7)
# memory usage: 7.2+ KB

# %%
df.head(5)
# Out:
#         source_name             author  \
# 0          Futurism  Victor Tangermann
# 1   Smithsonian.com         Sarah Kuta
# 2  Freerepublic.com            NY Post
# 3        Biztoc.com           cnbc.com
# 4              NASA               None
#
#                                                title  \
# 0  Congresswoman Makes Strange Claims About the E...
# 1  When Are the Next Solar Eclipses? 2026 Promise...
# 2  Biden mocked for shuffling around White House ...
# 3  Sierra Space CEO unveils new satellite product...
# 4  More Than 36,000 Volunteers Helped Do NASA Ecl...
#
#                                          description  \
# 0  In an embarrassing slipup, representative Shei...
# 1  The next total solar eclipse visible from the ...
# 2  President Biden raised eyebrows Wednesday morn...
# 3  Amid preparations for its spaceplane's maiden ...
# 4  Thank you for helping us out! Over 36,000 peop...
#
#                                                  url  \
# 0  https://futurism.com/the-byte/congresswoman-st...
# 1  https://www.smithsonianmag.com/smart-news/when...
# 2  https://freerepublic.com/focus/f-news/4230338/...
# 3              https://biztoc.com/x/79629db2e2d30a1d
# 4  https://science.nasa.gov/get-involved/citizen-...
#
#                                           urlToImage  \
# 0  https://wp-assets.futurism.com/2024/04/congres...
# 1  https://th-thumbnailer.cdn-si-edu.com/bz2aHBfu...
# 2                                               None
# 3     https://c.biztoc.com/p/79629db2e2d30a1d/s.webp
# 4  https://science.nasa.gov/wp-content/uploads/20...
#
#                 publishedAt  year  month  day
# 0 2024-04-10 20:00:41+00:00  2024  April   10
# 1 2024-04-10 19:58:12+00:00  2024  April   10
# 2 2024-04-10 19:53:11+00:00  2024  April   10
# 3 2024-04-10 19:50:06+00:00  2024  April   10
# 4 2024-04-10 19:47:05+00:00  2024  April   10

# %%
data
# Out:
# {'status': 'ok',
#  'totalResults': 7647,
#  'articles': [{'source': {'id': None, 'name': 'Futurism'},
#    'author': 'Victor Tangermann',
#    'title': "Congresswoman Makes Strange Claims About the Earth's Moon",
#    'description': 'In an embarrassing slipup, representative Sheila Jackson Lee (D-TX) told a high school audience on Monday that the Moon was a "planet" that is "made up of mostly gases." During the event, which took place before the total eclipse that plunged much of Texas in…',
#    'url': 'https://futurism.com/the-byte/congresswoman-strange-claims-earth-moon',
#    'urlToImage': 'https://wp-assets.futurism.com/2024/04/congresswoman-strange-claims-earth-moon.jpg',
#    'publishedAt': '2024-04-10T20:00:41Z',
#    'content': 'Yikes.\r\nLunar Blunder\r\nIn an embarrassing slipup, representative Sheila Jackson Lee (D-TX) told a high school audience on Monday that the Moon was a "planet" that\'s yes, really "made up of mostly gas… [+2134 chars]'},
#   {'source': {'id': None, 'name': 'Smithsonian.com'},
#    'author': 'Sarah Kuta',
#    'title': 'When Are the Next Solar Eclipses? 2026 Promises Totality in Europe, While Much of America Has a Decades-Long Wait',
#    'description': 'The next total solar eclipse visible from the contiguous U.S. won’t take place until August 23, 2044—but eclipse chasers will have other opportunities to experience totality before that',
#    'url': 'https://www.smithsonianmag.com/smart-news/when-are-the-next-solar-eclipses-2026-promises-totality-in-europe-while-much-of-america-has-a-decades-long-wait-180984129/',
#    'urlToImage': 'https://th-thumbnailer.cdn-si-edu.com/bz2aHBfu7z3sdtf6ZKTmADb3HXU=/fit-in/1600x0/filters:focal(1500x1007:1501x1008)/https%3A%2F%2Ftf-cmsv2-smithsonianmag-media.s3.amazonaws.com%2Ffiler_public%2Fd9%2F3f%2Fd93ff800-73dc-47fa-97f3-ef0d1ecf5ece%2Fgettyimages-2147666813.jpg',
#    'publishedAt': '2024-04-10T19:58:12Z',
#    'content': "Tens of millions of people watched Monday's total solar eclipse.\r\n Gregory Shamus / Getty Images\r\nTens of millions of North Americans watched in awe as the moon passed in front of the sun on Monday, … [+5222 chars]"},
#   {'source': {'id': None, 'name': 'Freerepublic.com'},
#    'author': 'NY Post',
#    'title': 'Biden mocked for shuffling around White House lawn with dazed look during Japanese PM ceremony',
#    'description': 'President Biden raised eyebrows Wednesday morning, when he appeared disoriented while welcoming Japanese Prime Minister Fumio Kishida to the White House for a state visit. Biden, 81, and Kishida, 66, greeted one another before shaking the hands of members of …',
#    'url': 'https://freerepublic.com/focus/f-news/4230338/posts',
#    'urlToImage': None,
#    'publishedAt': '2024-04-10T19:53:11Z',
#    'content': 'Skip to comments.\r\nBiden mocked for shuffling around White House lawn with dazed look during Japanese PM ceremonyNY Post ^\r\n | 04/10/2024\r\n | Ryan King\r\nPosted on 04/10/2024 12:53:11 PM PDT by Chicag… [+1422 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'cnbc.com',
#    'title': 'Sierra Space CEO unveils new satellite product ahead of Dream Chaser launch, possible IPO',
#    'description': "Amid preparations for its spaceplane's maiden flight and an initial public offering as soon as next year, Sierra Space is expanding its satellite offerings. Ahead of the much-anticipated solar eclipse, the commercial space unicorn unveiled its aptly named Ecl…",
#    'url': 'https://biztoc.com/x/79629db2e2d30a1d',
#    'urlToImage': 'https://c.biztoc.com/p/79629db2e2d30a1d/s.webp',
#    'publishedAt': '2024-04-10T19:50:06Z',
#    'content': "Amid preparations for its spaceplane's maiden flight and an initial public offering as soon as next year, Sierra Space is expanding its satellite offerings.Ahead of the much-anticipated solar eclipse… [+285 chars]"},
#   {'source': {'id': None, 'name': 'NASA'},
#    'author': None,
#    'title': 'More Than 36,000 Volunteers Helped Do NASA Eclipse Scienc',
#    'description': 'Thank you for helping us out! Over 36,000 people helped do NASA Science during Monday’s total solar eclipse. Together, these volunteers submitted more than 60,000 vital pieces of eclipse data to NASA science projects. More than 30,000 volunteers with the\xa0SunS…',
#    'url': 'https://science.nasa.gov/get-involved/citizen-science/more-than-36000-volunteers-helped-do-nasa-eclipse-scienc/',
#    'urlToImage': 'https://science.nasa.gov/wp-content/uploads/2024/04/eclipse-sequence-2024.04.0830.png?w=640',
#    'publishedAt': '2024-04-10T19:47:05Z',
#    'content': 'Many more volunteers used specialized gearDSLR cameras, telescopes, audiomoth recorders, and Ham Radio setstaking data for the\xa0Dynamic Eclipse Broadcast Initiative,\xa0the\xa0Eclipse Megamovie\xa0project,\xa0Cit… [+230 chars]'},
#   {'source': {'id': None, 'name': 'NASA'},
#    'author': None,
#    'title': 'More Than 36,000 Volunteers Helped Do NASA Eclipse Science',
#    'description': 'Thank you for helping us out! Over 36,000 people helped do NASA Science during Monday’s total solar eclipse. Together, these volunteers submitted more than 60,000 vital pieces of eclipse data to NASA science projects. More than 30,000 volunteers with the\xa0SunS…',
#    'url': 'https://science.nasa.gov/get-involved/citizen-science/more-than-36000-volunteers-helped-do-nasa-eclipse-science/',
#    'urlToImage': 'https://science.nasa.gov/wp-content/uploads/2024/04/eclipse-sequence-2024.04.0830.png?w=640',
#    'publishedAt': '2024-04-10T19:47:05Z',
#    'content': 'Many more volunteers used specialized gearDSLR cameras, telescopes, audiomoth recorders, and Ham Radio setstaking data for the\xa0Dynamic Eclipse Broadcast Initiative,\xa0the\xa0Eclipse Megamovie\xa0project,\xa0Cit… [+230 chars]'},
#   {'source': {'id': None, 'name': 'Droid Life'},
#    'author': 'Kellen',
#    'title': 'T-Mobile’s “Broadband Facts” Tell You Everything About Plans, Including Fees and Speeds',
#    'description': 'It was April Fools Day, and so I wasn’t paying attention to many announcements, because the days of companies trolling us all have ground my brain into the most negative state on April 1 each year, but T-Mobile had real news to share. Last week, T-Mobile anno…',
#    'url': 'https://www.droid-life.com/2024/04/10/t-mobiles-broadband-facts-tell-you-everything-about-plans-including-fees-and-speeds/',
#    'urlToImage': 'https://www.droid-life.com/wp-content/uploads/2024/01/T-Life-T-Mobile-Tuesdays-App-2-600x315-cropped.jpg',
#    'publishedAt': '2024-04-10T19:45:26Z',
#    'content': 'It was April Fools Day, and so I wasn’t paying attention to many announcements, because the days of companies trolling us all have ground my brain into the most negative state on April 1 each year, b… [+2519 chars]'},
#   {'source': {'id': None, 'name': 'Perfil.com'},
#    'author': 'Johanna Chiesa',
#    'title': 'El mensaje de la China Suárez tras los diferentes rumores de su relación con Marcos Ginocchio',
#    'description': 'La actriz y cantante utilizó sus historias para revelar qué la enamora de una persona. Leer más',
#    'url': 'https://caras.perfil.com/noticias/celebridades/china-suarez-marcos-ginocchio-mensaje-versiones-rumores.phtml',
#    'urlToImage': 'https://fotos.perfil.com/2024/04/10/trim/1140/641/la-china-suarez-y-marcos-ginocchio-1783163.jpg',
#    'publishedAt': '2024-04-10T19:44:44Z',
#    'content': 'La China Suárezse encuentra grabando en San Martín de los Andes, y al no poder dormirse decidió utilizar sus redes sociales para tener un ida y vuelta con sus seguidores. En ese contexto y tras prota… [+1116 chars]'},
#   {'source': {'id': None, 'name': 'The Boston Globe'},
#    'author': 'Dave Epstein',
#    'title': 'What’s up with spring? Weather this time of year is chaotic — for a reason.',
#    'description': 'The atmosphere this time of year lies somewhere between the cold of winter and the heat of summer and can waffle dramatically.',
#    'url': 'https://www.bostonglobe.com/2024/04/10/metro/boston-spring-forecast/',
#    'urlToImage': 'https://bostonglobe-prod.cdn.arcpublishing.com/resizer/hcYPAix33OTb_x0rgMQLI-qBhzU=/506x0/cloudfront-us-east-1.images.arcpublishing.com/bostonglobe/UBURYWYSWG3R72KKEU4KU3VKMI.JPG',
#    'publishedAt': '2024-04-10T19:38:21Z',
#    'content': 'We got quite lucky on Monday with crystal clear skies across Maine and other parts of Northern New England and just a few high clouds farther south and west. This led to a phenomenal eclipse experien… [+2717 chars]'},
#   {'source': {'id': None, 'name': 'CNBC'},
#    'author': None,
#    'title': 'Sierra Space CEO unveils new satellite product ahead of Dream Chaser launch, possible IPO',
#    'description': "CEO Tom Vice tells CNBC that the company's NASA-contracted space plane Dream Chaser is on pace to make its first flight in the fourth quarter.",
#    'url': 'https://www.cnbc.com/2024/04/10/sierra-space-ceo-talks-ipo-plans-satellite-launch-and-dream-chaser.html',
#    'urlToImage': None,
#    'publishedAt': '2024-04-10T19:37:38Z',
#    'content': "Amid preparations for its spaceplane's maiden flight and an initial public offering as soon as next year, Sierra Space is expanding its satellite offerings. \xa0\r\nAhead of the much-anticipated solar ecl… [+3811 chars]"},
#   {'source': {'id': None, 'name': 'Record.com.mx'},
#    'author': 'Record.com.mx',
#    'title': 'Estudio advierte que el Metro de la Ciudad de México podría sufrir nuevos accidentes',
#    'description': 'En el reporte se habla sobre los hundimientos irregulares que hay en la CDMX desde hace varios años',
#    'url': 'https://www.record.com.mx/contra/estudio-advierte-que-el-metro-de-la-ciudad-de-mexico-podria-sufrir-nuevos-accidentes',
#    'urlToImage': 'https://www.record.com.mx/sites/default/files/articulos/2024/04/10/accidentes_metro_1.jpg',
#    'publishedAt': '2024-04-10T19:35:56Z',
#    'content': 'Las fallas en el Sistema de Transporte Colectivo (STC) Metro podrían seguir e incluso está latente el riesgo de que haya nuevos accidentes, esto según un estudio que habla sobre el hundimiento en la … [+1563 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'feedfeeder',
#    'title': 'How to tell if you have eye damage after viewing the eclipse - WXII12 Winston-Salem',
#    'description': 'How to tell if you have eye damage after viewing the eclipseWXII12 Winston-Salem Solar eclipse glasses sold through Amazon, Illinois grocery stores recalled, Illinois Department of Public Health urgingWLS-TV Why Do My Eyes Hurt After Watching The Solar Eclips…',
#    'url': 'https://slashdot.org/firehose.pl?op=view&amp;id=173489284',
#    'urlToImage': None,
#    'publishedAt': '2024-04-10T19:33:12Z',
#    'content': 'Sign up for the Slashdot newsletter! OR check out the new Slashdot job board to browse remote jobs or jobs in your areaDo you develop on GitHub? You can keep using GitHub but automatically sync your … [+268 chars]'},
#   {'source': {'id': None, 'name': 'NASA'},
#    'author': 'Julia L. Bradshaw',
#    'title': 'A Langley Intern Traveled 1,340 Miles to View a Total Solar Eclipse. Here’s What She Saw.',
#    'description': 'Emma Friedman, an Office of Communications intern at NASA’s Langley Research Center in Hampton, Virginia, understood that the total solar eclipse on April 8th, 2024, was an out-of-this-world opportunity she couldn’t miss. Equipped with the proper eye protecti…',
#    'url': 'https://www.nasa.gov/centers-and-facilities/langley/a-langley-intern-traveled-1340-miles-to-view-a-total-solar-eclipse-heres-what-she-saw/',
#    'urlToImage': 'https://www.nasa.gov/wp-content/uploads/2024/04/emma-eclipse-1.jpg',
#    'publishedAt': '2024-04-10T19:32:02Z',
#    'content': 'Emma Friedman, an Office of Communications intern at NASAs Langley Research Center in Hampton, Virginia, understood that the total solar eclipse on April 8th, 2024, was an out-of-this-world opportuni… [+2940 chars]'},
#   {'source': {'id': None, 'name': 'My Modern Met'},
#    'author': 'Jessica Stewart',
#    'title': 'Epic Photos of Twin Planes Flying Through the Solar Eclipse',
#    'description': 'Epic Photos of Twin Planes Flying Through the Solar Eclipse\nThere are many memorable photos of the 2024 eclipse coming out, but two photographers really pushed themselves to the limit to create a unique take on the event. Dustin Snipes and Mason Mashon teamed…',
#    'url': 'https://mymodernmet.com/red-bull-total-eclipse-pilots/',
#    'urlToImage': 'https://mymodernmet.com/wp/wp-content/uploads/2024/04/redbull-aerobatic-pilots-2024-eclipse-thumbnail.jpg',
#    'publishedAt': '2024-04-10T19:20:26Z',
#    'content': 'Photo: Dustin Snipes and Mason Mashon\r\nThere are many memorable photos of the 2024 eclipse coming out, but two photographers really pushed themselves to the limit to create a unique take on the event… [+3914 chars]'},
#   {'source': {'id': None, 'name': 'Researchbuzz.me'},
#    'author': 'ResearchBuzz',
#    'title': 'Eclipse Image Generator, SARE Grant Projects, Google, More: Wednesday Afternoon ResearchBuzz, April 10, 2024',
#    'description': 'NEW RESOURCES Arizona State University: Computer science student creates new tool to make AI-generated art more sustainable. “Today, most AI solutions have been created by feeding large sets of data into networks […]',
#    'url': 'https://researchbuzz.me/2024/04/10/eclipse-image-generator-sare-grant-projects-google-more-wednesday-afternoon-researchbuzz-april-10-2024/',
#    'urlToImage': 'https://s0.wp.com/i/blank.jpg',
#    'publishedAt': '2024-04-10T19:16:37Z',
#    'content': 'NEW RESOURCES \r\nArizona State University: Computer science student creates new tool to make AI-generated art more sustainable. “Today, most AI solutions have been created by feeding large sets of dat… [+5019 chars]'},
#   {'source': {'id': None, 'name': 'Drunkenstepfather.com'},
#    'author': 'Jesus Martinez',
#    'title': 'Salma Hayek Gives You a Titty View of the Day',
#    'description': 'Old lady Salma Hayek who you may know as the big tits in the 90s and 00s that everyone was excited to have jump the fucking wall into America from Mexico because there’s just something about big tits that make you overlook the whole great replacement theory y…',
#    'url': 'https://drunkenstepfather.com/2024/04/10/salma-hayek-gives-you-a-titty-view-of-the-day',
#    'urlToImage': None,
#    'publishedAt': '2024-04-10T19:15:25Z',
#    'content': 'Old lady Salma Hayek who you may know as the big tits in the 90s and 00s that everyone was excited to have jump the fucking wall into America from Mexico because there’s just something about big tits… [+702 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'nytimes.com',
#    'title': 'Did You Really Need to Be There to See the Eclipse?',
#    'description': 'Did You Really Need to Be There to See It? Trying to capture the eclipse on a cloudy day in Image City. #imagecity',
#    'url': 'https://biztoc.com/x/e7a3208e7c9cafc9',
#    'urlToImage': 'https://c.biztoc.com/p/e7a3208e7c9cafc9/s.webp',
#    'publishedAt': '2024-04-10T19:12:07Z',
#    'content': 'Did You Really Need to Be There to See It?Trying to capture the eclipse on a cloudy day in Image City.\r\n#imagecity\r\nThis story appeared on nytimes.com, .'},
#   {'source': {'id': None, 'name': 'Ig.com.br'},
#    'author': 'Canaltech, Canaltech',
#    'title': 'Cometa é descoberto e destruído no eclipse solar',
#    'description': 'Um cometa ficou visível durante o eclipse solar desta segunda (8), mas o objeto se aproximou tanto do Sol que acabou se desintegrando',
#    'url': 'https://tecnologia.ig.com.br/parceiros/canaltech/2024-04-10/cometa-e-descoberto-e-destruido-no-eclipse-solar.html',
#    'urlToImage': 'https://i0.statig.com.br/bancodeimagens/bb/pu/fl/bbpufljdovuy5nat9znsurv1b.jpg',
#    'publishedAt': '2024-04-10T19:06:32Z',
#    'content': 'Um pequeno cometa \r\nfoi descoberto, fotografado e destruído durante o eclipse solar na segunda-feira (8) sim, tudo aconteceu em apenas 24 horas. Segundo especialistas, eventos do tipo são incomuns. \r… [+2208 chars]'},
#   {'source': {'id': 'fox-news', 'name': 'Fox News'},
#    'author': 'Fox News',
#    'title': 'Rep. Jackson Lee ripped after defending her moon gaffe and blaming it on GOP: ‘Vote better people’',
#    'description': 'Social media users slammed Rep. Sheila Jackson Lee, D-Texas, after she tried to turn her moon gaffe on Republicans and conservatives mocking her for it.',
#    'url': 'https://www.foxnews.com/media/rep-jackson-lee-ripped-defending-moon-gaffe-and-blaming-gop-vote-better-people',
#    'urlToImage': 'https://static.foxnews.com/foxnews.com/content/uploads/2024/04/Jackson-Lee-Eclipse-Split.jpg',
#    'publishedAt': '2024-04-10T19:00:48Z',
#    'content': 'Social media users trashed Rep. Sheila Jackson Lee, D-Texas, after she turned her gaffe about the moon being "made of gases" into a slam of Republicans on social media Tuesday.\xa0\r\nReacting to the back… [+3214 chars]'},
#   {'source': {'id': None, 'name': 'Abril.com.br'},
#    'author': 'Maria Clara Rossini',
#    'title': 'Quando poderemos ver um eclipse solar total do Brasil?',
#    'description': 'O último eclipse visível do Brasil aconteceu em março de 2006. Anote na agenda quando será o próximo.',
#    'url': 'https://super.abril.com.br/ciencia/quando-poderemos-ver-um-eclipse-solar-total-do-brasil',
#    'urlToImage': 'https://super.abril.com.br/wp-content/uploads/2024/04/1004-eclipse-solar-brasil-super-site.jpg?quality=90&strip=info&crop=1&resize=1080,565',
#    'publishedAt': '2024-04-10T19:00:35Z',
#    'content': 'Assine SUPER por R$2,00/semanaContinua após publicidade\r\nPor Maria Clara Rossini\r\n 10 abr 2024, 16h00 \r\n\xa0(San Francisco Chronicle/Hearst Newspapers via Getty Images/Reprodução)\r\nContinua após publici… [+2351 chars]'},
#   {'source': {'id': None, 'name': 'Scientific American'},
#    'author': 'Clara Moskowitz, Elah Feder, Rachel Feltman',
#    'title': 'Did the Eclipse Give You the Amateur Astronomy Bug? Here’s How to Get Started',
#    'description': 'Chanda Prescod-Weinstein, a professional astronomer, talks about her own adventures in astrophotography—and offers tips and tricks for new amateur astronomers.',
#    'url': 'https://www.scientificamerican.com/podcast/episode/did-the-eclipse-give-you-the-amateur-astronomy-bug-heres-how-to-get-started/',
#    'urlToImage': 'https://static.scientificamerican.com/dam/m/3510db04ae5ecdaf/original/amateur-astronomy-GettyImages-623220974.gif?w=600',
#    'publishedAt': '2024-04-10T19:00:00Z',
#    'content': '[CLIP: Music]\r\nClara Moskowitz: On April 8, millions and millions of people across North America got to glimpse a total solar eclipse. If that brief foray into backyard astronomy left you hungry for … [+15546 chars]'},
#   {'source': {'id': None, 'name': 'Queerty.com'},
#    'author': 'Cameron Scheetz',
#    'title': 'Johnny Sibilly’s “Dom” era, a ‘Heartstopper’ engagement & all the can’t-miss LGBTQ+ releases this week',
#    'description': "Stay in-the-know with Queerty's midweek pop culture catch-up.",
#    'url': 'https://www.queerty.com/johnny-sibillys-dom-era-a-heartstopper-engagement-all-the-cant-miss-lgbtq-releases-this-week-20240410',
#    'urlToImage': 'https://adabgmwwup.cloudimg.io/v7/_queerty-prodweb_/2024/04/screen-shot-2024-04-10-at-94945-am.png?auto=format&auto=compress&fit=crop&gravity=smart&w=1200&h=630&force_format=jpeg&wat=1&wat_gravity=southeast&wat_pad=70',
#    'publishedAt': '2024-04-10T19:00:00Z',
#    'content': 'Need a boost to get over Hump Day?\xa0The Hot Sheet\xa0is Queertys midweek pop culture catch-up, highlighting the entertainment stories everyones talking about, the ones you mightve missed, and the notable… [+6531 chars]'},
#   {'source': {'id': None, 'name': 'Xataka.com.mx'},
#    'author': 'Gonzalo Hernández',
#    'title': 'El eclipse solar logró algo inédito en México: que la gente se desconectara de internet',
#    'description': 'El 8 de abril de 2024 será un día memorable en México. Un eclipse solar total atravesó gran parte del país, oscureciendo el cielo por unos minutos y provocando un efecto secundario inesperado: que los mexicanos se desconectaran de internet por unas horas.\n<!-…',
#    'url': 'https://www.xataka.com.mx/telecomunicaciones/eclipse-solar-logro-algo-inedito-mexico-que-gente-se-desconectara-internet',
#    'urlToImage': 'https://i.blogs.es/6a491d/trafico-internet-eclipse/840_560.jpeg',
#    'publishedAt': '2024-04-10T18:59:54Z',
#    'content': 'El 8 de abril de 2024 será un día memorable en México. Un eclipse solar total atravesó gran parte del país, oscureciendo el cielo por unos minutos y provocando un efecto secundario inesperado: que lo… [+1666 chars]'},
#   {'source': {'id': None, 'name': 'Eluniversal.com.co'},
#    'author': 'EFE',
#    'title': 'Rusia vuelve a suspender lanzamiento de cohete',
#    'description': 'Rusia suspendió el miércoles, en el último momento y por segundo día consecutivo, el lanzamiento del cohete pesado Angará-A5 desde el cosmódromo Vostochni, en el Lejano Oriente ruso.',
#    'url': 'https://www.eluniversal.com.co/ciencia/rusia-vuelve-a-suspender-lanzamiento-de-cohete-AD10318998',
#    'urlToImage': 'https://www.eluniversal.com.co/binrepository/915x686/58c0/800d686/none/13704/XHER/angara-a5_9862574_20240410135922.jpg',
#    'publishedAt': '2024-04-10T18:59:16Z',
#    'content': 'Rusia suspendió el miércoles, en el último momento y por segundo día consecutivo, el lanzamiento del cohete pesado Angará-A5 desde el cosmódromo Vostochni, en el Lejano Oriente ruso.\r\nAl igual que el… [+1741 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'thewrap.com',
#    'title': 'Tamron Hall Jokes After Studio Fire: ‘We Had a Real Smoke Show Around Here’',
#    'description': 'After a grease fire broke out on “The Tamron Hall Show” on Wednesday, the host gave a live update in which she thanked her staff, firefighters and the audience, and promised to be back live on Thursday after re-airing Monday’s eclipse episode. “Everybody’s OK…',
#    'url': 'https://biztoc.com/x/3b6e34603fde777c',
#    'urlToImage': 'https://c.biztoc.com/p/3b6e34603fde777c/s.webp',
#    'publishedAt': '2024-04-10T18:58:07Z',
#    'content': 'After a grease fire broke out on The Tamron Hall Show on Wednesday, the host gave a live update in which she thanked her staff, firefighters and the audience, and promised to be back live on Thursday… [+265 chars]'},
#   {'source': {'id': None, 'name': '[Removed]'},
#    'author': None,
#    'title': '[Removed]',
#    'description': '[Removed]',
#    'url': 'https://removed.com',
#    'urlToImage': None,
#    'publishedAt': '1970-01-01T00:00:00Z',
#    'content': '[Removed]'},
#   {'source': {'id': None, 'name': 'STLtoday.com'},
#    'author': 'By Jack Suntrup St. Louis Post-Dispatch',
#    'title': 'Parson wrong to rescind stay of execution, attorneys tell Missouri Supreme Court',
#    'description': 'Attorneys for death row inmate Marcellus Williams, convicted of killing ex-Post-Dispatch reporter Lisha Gayle, are challenging Gov. Mike Parson’s move to rescind a previous stay of execution and dissolve a Board of Inquiry that had been looking into his case.',
#    'url': 'https://www.stltoday.com/news/local/crime-courts/parson-wrong-to-rescind-stay-of-execution-attorneys-tell-missouri-supreme-court/article_dae2681a-f6a1-11ee-aa3f-6bcdcd6a4ac3.html',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/5/f1/5f194f0e-94cf-5d3b-b886-8bb7581d25e2/65bf9b8fdd992.image.jpg?crop=701%2C368%2C0%2C54&resize=701%2C368&order=crop%2Cresize',
#    'publishedAt': '2024-04-10T18:57:00Z',
#    'content': 'JEFFERSON CITY The Missouri Supreme Court is reviewing Gov. Mike Parsons decision last summer to scrap an order halting the execution of a man convicted in the 1998 murder of a former Post-Dispatch r… [+4088 chars]'},
#   {'source': {'id': None, 'name': 'Powder Magazine'},
#    'author': 'Ella Boyd',
#    'title': 'Closing Dates Announced For Vermont Ski Resorts',
#    'description': 'Because you want to know where to ski now, and where to ski last, we have compiled the closing dates for Vermont resorts Stowe, Smuggs, Jay, Stratton, Mt. Snow, Okemo, Killington, and Sugarbush.',
#    'url': 'https://www.powder.com/trending-news/vermont-ski-closing-day-winter-24',
#    'urlToImage': 'https://www.powder.com/.image/t_share/MjA0ODYxMzM5NjE1NjM1MDM4/untitled-design-421.png',
#    'publishedAt': '2024-04-10T18:54:38Z',
#    'content': "Vermont has had a successful season. Copious amounts of snow, being in the path of totality for the recent solar eclipse, and although they had one of their warmest seasons ever, their snowfall didn'… [+3286 chars]"},
#   {'source': {'id': None, 'name': 'Futurism'},
#    'author': 'Sharon Adarlo',
#    'title': "Here's What NASA's Rovers See During an Eclipse on Mars",
#    'description': 'Celestial Blip Earth is not the only place in our Solar System where humans have captured solar eclipses like the one this past Monday that casted shadows over parts of North America. Because NASA has the Perseverance rover parked on the surface of the Red Pl…',
#    'url': 'https://futurism.com/the-byte/nasa-rover-eclipse-mars',
#    'urlToImage': 'https://wp-assets.futurism.com/2024/04/nasa-rover-eclipse-mars.jpg',
#    'publishedAt': '2024-04-10T18:54:31Z',
#    'content': "These moons are smaller and way lumpier, but their transits in front of the Sun are still special.\r\nCelestial Blip\r\nEarth isn't the only place in our solar system where humans have observed a solar e… [+2574 chars]"},
#   {'source': {'id': None, 'name': 'Albertmohler.com'},
#    'author': 'Graham Faulkner',
#    'title': 'Abortion is constitutive of the nation? France becomes the first nation to put abortion rights into its constitution',
#    'description': 'In France, abortion is now a constitutional right. On Monday, France became the first nation to enshrine abortion rights in its constitution. Both chambers of the French Parliament passed the measure with overwhelming majorities, and they were supported by Fr…',
#    'url': 'https://albertmohler.com/2024/04/10/abortion-is-constitutive-of-the-nation-france-becomes-the-first-nation-to-put-abortion-rights-into-its-constitution/',
#    'urlToImage': 'https://mohler.s3.amazonaws.com/uploads/2024/04/france-abortion-featured.jpg',
#    'publishedAt': '2024-04-10T18:47:58Z',
#    'content': 'In France, abortion is now a constitutional right. On Monday, France became the first nation to enshrine abortion rights in its constitution. Both chambers of the French Parliament passed the measure… [+5156 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Ash Parrish',
#    'title': 'Amazon’s Fallout show gets the postapocalyptic vibes exactly right',
#    'description': 'Amazon’s Fallout TV series strikes the perfect tone of the games with immaculate post-apocalyptic vibes and a great performance by Walter Goggins as The Ghoul.',
#    'url': 'https://www.theverge.com/24126474/fallout-review-amazon-prime-video',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/i4wvp5rxLiDhR9C-vqkTTxIokDU=/0x0:2999x1242/1200x628/filters:focal(1066x490:1067x491)/cdn.vox-cdn.com/uploads/chorus_asset/file/25126271/FALLOUT_S1_480_vX002.00086464_3000.jpg',
#    'publishedAt': '2024-04-10T18:47:38Z',
#    'content': 'Amazons Fallout show gets the postapocalyptic vibes exactly right\r\nAmazons Fallout show gets the postapocalyptic vibes exactly right\r\n / Its Fallouts jokes, rather than its plot, that make it one of … [+4792 chars]'},
#   {'source': {'id': None, 'name': 'Bringatrailer.com'},
#    'author': 'bringatrailer',
#    'title': '1987 Cadillac Allante at No Reserve',
#    'description': 'This 1987 Cadillac Allanté was first registered in Missouri, and it later spent time in Arkansas, Virginia, and Delaware berfore it was acquired by the seller on BaT in June 2023. Powered by a 4.1-liter V8 paired with a four-speed automatic transaxle, the car…',
#    'url': 'https://bringatrailer.com/listing/1987-cadillac-allante-16/',
#    'urlToImage': 'https://bringatrailer.com/wp-content/uploads/2024/02/1987_cadillac_allante_a3e73345-1b69-4634-ab14-d672cd3daeaa-03677.jpeg',
#    'publishedAt': '2024-04-10T18:45:11Z',
#    'content': 'This 1987 Cadillac Allanté was first registered in Missouri, and it later spent time in Arkansas, Virginia, and Delaware berfore it was acquired by the seller on BaT in June 2023. Powered by a 4.1-li… [+3259 chars]'},
#   {'source': {'id': None, 'name': 'STLtoday.com'},
#    'author': 'By Steph Kukuljan St. Louis Post-Dispatch',
#    'title': 'BJC buys former Panera Bread headquarters in Sunset Hills',
#    'description': 'Panera Bread, known locally as St. Louis Bread Co., left the property last year for smaller office space in Fenton.',
#    'url': 'https://www.stltoday.com/news/local/metro/bjc-buys-former-panera-bread-headquarters-in-sunset-hills/article_918d15c2-f762-11ee-bffa-db44aa49f1e7.html',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/3/6d/36deda73-fc77-5d2a-9325-656f093aef04/618b51d382351.image.jpg?crop=750%2C394%2C0%2C20&resize=750%2C394&order=crop%2Cresize',
#    'publishedAt': '2024-04-10T18:45:00Z',
#    'content': 'SUNSET HILLS\xa0 BJC Health has purchased the former headquarters of Panera Bread in south St. Louis County.\xa0\r\nThe health care system bought the 116,300-square-foot building, at Watson and South Geyer r… [+3511 chars]'},
#   {'source': {'id': None, 'name': 'Record.com.mx'},
#    'author': 'Record.com.mx',
#    'title': 'OEA respalda a México y condena “enérgicamente” a Ecuador por entrar violentamente a la Embajada de nuestro país',
#    'description': 'Pese a sus diferencias, AMLO aplaudió la postura de la Organización de los Estados Americanos en este conflicto',
#    'url': 'https://www.record.com.mx/contra/oea-respalda-a-mexico-y-condena-energicamente-a-ecuador-por-entrar-violentamente-a-la',
#    'urlToImage': 'https://www.record.com.mx/sites/default/files/articulos/2024/04/10/oea_ecuador_mexico_4.jpg',
#    'publishedAt': '2024-04-10T18:41:48Z',
#    'content': 'La Organización de los Estados Americanos (OEA) condenó enérgicamente a Ecuador luego de que hace unos días entró con violencia a la sede de la Embajada en México en aquel país, expulsado incluso a l… [+1221 chars]'},
#   {'source': {'id': None, 'name': 'Olhardigital.com.br'},
#    'author': 'Flavia Correia',
#    'title': 'Cometa é visto pela primeira vez no dia do eclipse e morre logo após ser descoberto',
#    'description': 'Batizado de "SOHO-5008", o cometa foi descoberto no dia do eclipse solar total por um astrônomo amador tailandês\nO post Cometa é visto pela primeira vez no dia do eclipse e morre logo após ser descoberto apareceu primeiro em Olhar Digital.',
#    'url': 'https://olhardigital.com.br/2024/04/10/ciencia-e-espaco/cometa-visto-pela-1a-vez-no-dia-do-eclipse-morre-apos-ser-descoberto/',
#    'urlToImage': 'https://olhardigital.com.br/wp-content/uploads/2024/04/eclipse-solar-cometa-OD-695x500.jpg',
#    'publishedAt': '2024-04-10T18:41:30Z',
#    'content': 'Um astrônomo amador chinês chamado Lin Zixuan estava em New Hampshire, nos EUA, para assistir e registrar o eclipse solar total de segunda-feira (8), quando acabou captando um cometa em plena desinte… [+2130 chars]'},
#   {'source': {'id': None, 'name': 'Ig.com.br'},
#    'author': 'iG Último Segundo, iG Último Segundo',
#    'title': 'Mulher dá a luz durante eclipse e batiza filha de Sol',
#    'description': 'Alicia Alvarez mora no Texas e sua segunda filha nasceu duas semanas antes do previsto, coincidindo com o fenômeno de 8 de abril',
#    'url': 'https://ultimosegundo.ig.com.br/mundo/2024-04-10/bebe-dos-eua-nasce-no-dia-do-eclipse-e-recebe-o-nome-de-sol.html',
#    'urlToImage': 'https://i0.statig.com.br/bancodeimagens/8y/dg/hw/8ydghwm86m0xg47dy9dbvh7yo.jpg',
#    'publishedAt': '2024-04-10T18:38:16Z',
#    'content': 'Uma família do Texas (Estados Unidos) recebeu a segunda filha durante o\xa0 eclipe total solar que aconteceu no último dia 8 de abril.\r\nCom o parto previsto para 14 de abril, os Alvarez receberam a bebê… [+1051 chars]'},
#   {'source': {'id': None, 'name': 'Snopes.com'},
#    'author': 'Nur Ibrahim',
#    'title': "US Rep. Sheila Jackson Lee Said Moon Is Planet and Made Up of 'Gases'?",
#    'description': 'Texas U.S. Rep. Sheila Jackson Lee referred to the moon as a planet and said, “A full moon is that complete, rounded circle which is made up mostly of gases, and that’s why the question is why or how could we as humans live on the moon?”',
#    'url': 'https://www.snopes.com//fact-check/sheila-jackson-lee-moon/',
#    'urlToImage': 'https://mediaproxy.snopes.com/width/1200/https://media.snopes.com/2024/04/shelia_jackson_lee.png',
#    'publishedAt': '2024-04-10T18:38:00Z',
#    'content': 'Claim:\r\nTexas U.S. Rep. Sheila Jackson Lee referred to the moon as a planet and said, A full moon is that complete, rounded circle which is made up mostly of gases, and thats why the question is why … [+3095 chars]'},
#   {'source': {'id': None, 'name': 'Tubefilter'},
#    'author': 'Sam Gutelle',
#    'title': 'Top 50 Most Viewed U.S. YouTube Channels • Week Of 04/07/2024',
#    'description': "MrBeast moved up two spots to claim the #1 spot in the U.S. Top 50.\xa0Jimmy Donaldson's primary YouTube channel typically experiences viewership surges in the days that follow new video releases, and the first week of April was no exception. Donaldson's week-lo…",
#    'url': 'https://www.tubefilter.com/?p=179521',
#    'urlToImage': 'https://www.tubefilter.com/wp-content/uploads/2024/04/tricksters-youtube-shorts.jpg',
#    'publishedAt': '2024-04-10T18:33:06Z',
#    'content': '[Editor’s Note: Tubefilter Charts is a weekly rankings column from Tubefilter with data provided by GospelStats. It’s exactly what it sounds like: a top number ranking of YouTube channels based on st… [+4795 chars]'},
#   {'source': {'id': None, 'name': 'Live Science'},
#    'author': 'Harry Baker',
#    'title': "No, you didn't see a solar flare during the total eclipse — but you may have seen something just as special",
#    'description': 'Several media outlets have incorrectly claimed that explosive solar flares were spotted during the April 8 total solar eclipse. But there were no flares during totality, so what did people see?',
#    'url': 'https://www.livescience.com/space/the-sun/no-you-didnt-see-a-solar-flare-during-the-total-eclipse-but-you-may-have-seen-something-just-as-special',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/5rPZMHzoGHZaABnj93EF9M-1200-80.jpg',
#    'publishedAt': '2024-04-10T18:23:35Z',
#    'content': 'During the recent total solar eclipse\r\n, you may have glimpsed what looked like explosive solar flares bursting from the sun after its fiery corona briefly came into view. But it turns out this was n… [+3377 chars]'},
#   {'source': {'id': None, 'name': 'TheWrap'},
#    'author': 'Sharon Knolle',
#    'title': 'Tamron Hall Jokes After Studio Fire: ‘We Had a Real Smoke Show Around Here’ | Video',
#    'description': 'The TV host adds, "sometimes life be life-ing." \nThe post Tamron Hall Jokes After Studio Fire: ‘We Had a Real Smoke Show Around Here’ | Video appeared first on TheWrap.',
#    'url': 'https://www.thewrap.com/tamron-hall-update-studio-fire-video/',
#    'urlToImage': 'https://www.thewrap.com/wp-content/uploads/2024/04/tamron-hall-fire.jpg',
#    'publishedAt': '2024-04-10T18:22:09Z',
#    'content': 'After a grease fire broke out on The Tamron Hall Show on Wednesday, the host gave a live update in which she thanked her staff, firefighters and the audience, and promised to be back live on Thursday… [+1839 chars]'},
#   {'source': {'id': None, 'name': 'Daily Signal'},
#    'author': 'Jay Greene',
#    'title': 'Education Eclipsed: Unnecessary School Closures Breed Anxious Children',
#    'description': 'A total eclipse crossed the country this week in a display of natural wonder. Rather than seize the opportunity for an engaging science lesson, hundreds... Read More\nThe post Education Eclipsed: Unnecessary School Closures Breed Anxious Children appeared firs…',
#    'url': 'https://www.dailysignal.com/2024/04/10/education-eclipsed-unnecessary-school-closures-breed-anxious-children/',
#    'urlToImage': 'https://first-heritage-foundation.s3.amazonaws.com/live_files/2024/04/20240410_EducationEclipsed-scaled.jpg',
#    'publishedAt': '2024-04-10T18:18:35Z',
#    'content': 'A total eclipse crossed the country this week in a display of natural wonder. Rather than seize the opportunity for an engaging science lesson, hundreds of school districts with several hundred thous… [+5225 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Martin Z. Braun',
#    'title': 'NY Pension Costs to Rise by More Than $4 Billion Under New Plan',
#    'description': '(Bloomberg) -- Taxpayer contributions to New York City and state pensions would rise by more than $4 billion if Governor Kathy Hochul yields to a legislative...',
#    'url': 'https://finance.yahoo.com/news/ny-pension-costs-rise-more-181829773.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/0kcGo9QHx5lml6X6mTuhpA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/bloomberg_markets_842/b9b59bd3e9633690eef9bfed2b597829',
#    'publishedAt': '2024-04-10T18:18:29Z',
#    'content': '(Bloomberg) -- Taxpayer contributions to New York City and state pensions would rise by more than $4 billion if Governor Kathy Hochul yields to a legislative proposal that would sweeten benefits for … [+4687 chars]'},
#   {'source': {'id': None, 'name': 'Atlas Obscura'},
#    'author': 'Jennifer Byrne',
#    'title': 'The Solar Eclipse Time Capsules of Small Town America',
#    'description': 'Food items and time capsules aren’t necessarily a match made in heaven, but for their 2024 solar eclipse time capsule, the Firelands Historical Society in Norwalk, Ohio, couldn’t resist the wordplay of including a Moon Pie.\nSealed and tucked away in an undisc…',
#    'url': 'https://www.atlasobscura.com/articles/next-eclipse-time-capsule',
#    'urlToImage': 'https://img.atlasobscura.com/Pjo1a9j7Te3j44uo1O5xo6_Bc_z4cRvmvrh8yjTBbAs/rt:fit/w:600/q:81/sm:1/scp:1/ar:1/aHR0cHM6Ly9hdGxh/cy1kZXYuczMuYW1h/em9uYXdzLmNvbS91/cGxvYWRzL2Fzc2V0/cy9kOWViZmM0Njgx/Zjc1NTNlMzdfZ2lh/bnQgc2xvdGggYW5k/IGhpc3RvcmljYWwg/c29jIG1lbWJlcnMg/d2hlbiBpcyB0aGUg/bmV4dCBlY2xpcHNl/IHNvbGFyIGVjbGlw/c2UgdGltZSBjYXBz/dWxlLmpwZWc.jpg',
#    'publishedAt': '2024-04-10T18:15:00Z',
#    'content': 'Food items and time capsules aren’t necessarily a match made in heaven, but for their 2024 solar eclipse time capsule, the Firelands Historical Society in Norwalk, Ohio, couldn’t resist the wordplay … [+4858 chars]'},
#   {'source': {'id': None, 'name': 'Cosmopolitan.com'},
#    'author': 'Mehera  Bonner',
#    'title': "The Best Fan Theories About Every. Single. Track. From Taylor Swift's 'The Tortured Poets Department'",
#    'description': "Here are the best fan theories for every single track on Taylor Swift's album 'The Tortured Poets Department,' which comes out soon.",
#    'url': 'https://www.cosmopolitan.com/entertainment/music/a60442273/tortured-poets-department-best-theories/',
#    'urlToImage': 'https://hips.hearstapps.com/hmg-prod/images/jonathan-majors-episode-1811-pictured-musical-guest-taylor-news-photo-1712763026.jpg?crop=0.779xw:0.584xh;0.126xw,0.237xh&resize=1200:*',
#    'publishedAt': '2024-04-10T18:12:00Z',
#    'content': "We're T-minus a few days away from Taylor Swift's The Tortured Poets Department dropping on April 19, and fans have already managed to analyze the (potential!) meaning behind every song on the album … [+7615 chars]"},
#   {'source': {'id': None, 'name': 'STLtoday.com'},
#    'author': 'Colleen Long | Associated Press',
#    'title': 'Unpopularity of abortion bans could help Democrats, including in states like Missouri',
#    'description': 'About two-thirds of Americans say abortion should generally be legal, according to polling by The Associated Press-NORC Center for Public Affairs Research.',
#    'url': 'https://www.stltoday.com/news/local/government-politics/unpopularity-of-abortion-bans-could-help-democrats-including-in-states-like-missouri/article_9941b8ac-f746-11ee-94c1-031e17a5bedd.html',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/9/94/9941b8ac-f746-11ee-94c1-031e17a5bedd/6616a4eb9bf12.preview.jpg?crop=1024%2C538%2C0%2C55&resize=1024%2C538&order=crop%2Cresize',
#    'publishedAt': '2024-04-10T18:11:00Z',
#    'content': 'Colleen Long | Associated Press\r\nWASHINGTON For most of her life, Angela Crawford considered herself a fairly conservative Republican and she voted that way. But then a wave of court rulings and Repu… [+8344 chars]'},
#   {'source': {'id': None, 'name': 'Eclipse.org'},
#    'author': 'Jacob Harris',
#    'title': 'Eclipse Theia IDE: A Look at Leaps in Performance',
#    'description': 'Eclipse Theia IDE: A Look at Leaps in Performance\n\nJacob Harris\n\nWed, 2024-04-10 14:03\n\n\n With Eclipse Theia IDE arriving on the scene, developers have another viable contender that offers rich features, a vibrant community and a tight experience.\r\n\n \n \n URL\r…',
#    'url': 'https://blogs.eclipse.org/post/john-kellerman/eclipse-theia-ide-look-leaps-performance',
#    'urlToImage': 'https://www.eclipse.org/eclipse.org-common/themes/solstice/public/images/logo/eclipse-foundation-400x400.png',
#    'publishedAt': '2024-04-10T18:03:09Z',
#    'content': 'Developers hate waiting. In the ever-evolving landscape of Integrated Development Environments (IDEs), the quest for swifter, more efficient tools remains a constant pursuit. Enter Eclipse Theia IDE.… [+4887 chars]'},
#   {'source': {'id': None, 'name': 'Tecmundo.com.br'},
#    'author': 'Jorge Marin',
#    'title': 'Como o eclipse solar total comprovou a teoria da gravidade de Einstein; entenda',
#    'description': 'No dia 8 de abril, milhares de pessoas assistiram à sombra da Lua bloqueando o Sol, durante o chamado Grande Eclipse Norte-Americano de 2024. O fenômeno, visível em um corredor de 160 quilômetros de largura, atravessou regiões do México, EUA e Canadá. Só que,…',
#    'url': 'https://www.tecmundo.com.br/ciencia/281839-eclipse-solar-total-comprovou-teoria-gravidade-einstein-entenda.htm',
#    'urlToImage': 'https://tm.ibxk.com.br/2024/04/10/10101217779056.jpg',
#    'publishedAt': '2024-04-10T18:00:00Z',
#    'content': 'No dia 8 de abril, milhares de pessoas assistiram à sombra da Lua bloqueando o Sol,durante o chamado Grande Eclipse Norte-Americano de 2024. O fenômeno, visível em um corredor de 160 quilômetros de l… [+2887 chars]'},
#   {'source': {'id': 'fox-news', 'name': 'Fox News'},
#    'author': 'Christina Coulter',
#    'title': "New York pediatrician's daughter says Airstream trailer had 'safety oversight' in fatal mishap: report",
#    'description': "Pediatrician Monika Woroniecka was flung onto the highway trying to close her trailer's door – her daughter said a fatal flaw in design could have contributed to her death.",
#    'url': 'https://www.foxnews.com/us/new-york-pediatricians-daughter-says-airstream-trailer-safety-oversight-fatal-mishap-report',
#    'urlToImage': 'https://static.foxnews.com/foxnews.com/content/uploads/2024/04/Monika_woroniecka_split.jpg',
#    'publishedAt': '2024-04-10T17:59:13Z',
#    'content': 'The daughter of a Long Island pediatrician who was fatally flung from an Airstream over the weekend said a "significant oversight" in the trailer\'s design contributed to the tragic accident.\r\nHorrifi… [+5220 chars]'},
#   {'source': {'id': None, 'name': 'Huffingtonpost.es'},
#    'author': 'Redacción HuffPost',
#    'title': "‘Saldremos mejores' o ‘Malas Personas’, entre los ganadores de los Premios Ondas Globales del Podcast",
#    'description': '<![CDATA[<p>Los podcasts Saldremos mejores, Malas Personas, Todopoderosos, Corderos, A solas con… Vicky Martín Berrocal, Meterse al rancho, los podcasters Xuso Jones y Ana Brito y el actor Víctor Clavijo, entre otros, se encuentran entre los galardonados de l…',
#    'url': 'https://www.huffingtonpost.es/medios/saldremos-mejores-malas-personas-ganadores-premios-ondas-globales-podcast.html',
#    'urlToImage': 'https://img.huffingtonpost.es/files/og_thumbnail/uploads/2024/04/10/saldremos-mejores.jpeg',
#    'publishedAt': '2024-04-10T17:56:58Z',
#    'content': 'Los podcasts Saldremos mejores, Malas Personas, Todopoderosos, Corderos, A solas con Vicky Martín Berrocal, Meterse al rancho, los podcasters Xuso Jones y Ana Brito y el actor Víctor Clavijo, entre o… [+11076 chars]'},
#   {'source': {'id': None, 'name': 'Uol.com.br'},
#    'author': 'Bárbara Giovani',
#    'title': 'O que são os pontinhos vermelhos visíveis atrás do eclipse solar',
#    'description': 'Durante o último eclipse solar total, proeminências solares deram às caras ao redor da sombra lunar e chamaram a atenção dos curiosos\nThe post O que são os pontinhos vermelhos visíveis atrás do eclipse solar appeared first on Giz Brasil.',
#    'url': 'https://gizmodo.uol.com.br/o-que-sao-os-pontinhos-vermelhos-visiveis-atras-do-eclipse-solar/',
#    'urlToImage': 'https://gizmodo.uol.com.br/wp-content/blogs.dir/8/files/2024/04/proeminencia-solar-eclipse-solar.jpg',
#    'publishedAt': '2024-04-10T17:56:46Z',
#    'content': 'Na última segunda-feira (8), a Lua passou exatamente entre o Sol e da Terra, bloqueando a luz da estrela por alguns minutos em alguns locais da América do Norte. Em geral, um eclipse solar é um dos ú… [+1762 chars]'},
#   {'source': {'id': None, 'name': 'Record.com.mx'},
#    'author': 'Record.com.mx',
#    'title': '“Papi, no veo nada”; niño pierde la vista por ver el Eclipse Solar sin protección',
#    'description': 'En redes sociales circula el video de un pequeño que sufre daños en la vista luego de quitarse los lentes que tenía para ver el eclipse',
#    'url': 'https://www.record.com.mx/contra/papi-no-veo-nada-nino-pierde-la-vista-por-ver-el-eclipse-solar-sin-proteccion',
#    'urlToImage': 'https://www.record.com.mx/sites/default/files/articulos/2024/04/10/nino_eclipse_solar_1.jpg',
#    'publishedAt': '2024-04-10T17:54:08Z',
#    'content': 'En redes sociales se ha hecho viral el caso de un niño en los Estados Unidos, el cual perdió la vista luego de ver el Eclipse Solar Total del pasado 8 de abril, sin protección.\r\nEl video que ha sido … [+1703 chars]'},
#   {'source': {'id': None, 'name': 'Montevideo.com.uy'},
#    'author': 'Montevideo Portal',
#    'title': '¿Me pasa algo en los ojos? Las consultas que se dispararon en EE. UU. tras el eclipse',
#    'description': 'Quienes observaron el fenómeno sin proteger sus ojos se expusieron a daños. Hay síntomas que son buenos indicadores.',
#    'url': 'https://www.montevideo.com.uy/Salud/-Me-pasa-algo-en-los-ojos-Las-consultas-que-se-dispararon-en-EE-UU-tras-el-eclipse-uc885101',
#    'urlToImage': 'https://imagenes.montevideo.com.uy/imgnoticias/202404/_W933_80/877591.jpg',
#    'publishedAt': '2024-04-10T17:53:00Z',
#    'content': 'Después del eclipse solar total que fascinó a millones de\r\npersonas en América del Norte, los medios en Estados Unidos informan de la\r\npreocupación de muchos espectadores por la salud de sus ojos. Es… [+2108 chars]'},
#   {'source': {'id': None, 'name': 'CNBC'},
#    'author': None,
#    'title': 'Biden’s new student loan forgiveness plan could start eliminating debts before the 2024 presidential election',
#    'description': "The Biden administration is moving ahead quickly with its new student loan forgiveness plan, with hopes to start wiping out people's debts this fall.",
#    'url': 'https://www.cnbc.com/2024/04/10/biden-administration-could-start-forgiving-student-debt-this-year.html',
#    'urlToImage': None,
#    'publishedAt': '2024-04-10T17:49:11Z',
#    'content': "US President Joe Biden speaks about student loan relief at Madison College in Madison, Wisconsin, on April 8, 2024.\xa0\r\nA race to still forgive debt after Supreme Court verdict\r\nPresident Joe Biden's 2… [+5372 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': None,
#    'title': 'Lyrid meteor shower starts next week following solar eclipse: Why you should look up again',
#    'description': None,
#    'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_c78cb7db-eeef-4d7d-af10-6ff245dfc60c',
#    'urlToImage': None,
#    'publishedAt': '2024-04-10T17:38:44Z',
# ...
#    'title': 'Mountain goat stuck under Kansas City bridge survives rocky rescue',
#    'description': 'An escaped mountain goat that somehow got stuck under a Kansas City bridge now may be reunited with the owners who suspect he was stolen from their farm.',
#    'url': 'https://apnews.com/article/mountain-goat-bridge-rescue-kansas-city-68020ad0fae323f29bca6850ef33ca08',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/c/c5/cc5c0924-674a-5df6-9670-0a078273ba97/6615a3ca64eda.image.jpg?crop=1245%2C654%2C0%2C95&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2024-04-10T16:29:00Z',
#    'content': 'By HEATHER HOLLINGSWORTH - Associated Press\r\nAn escaped mountain goat that somehow got stuck under a Kansas City bridge has survived a rocky rescue effort and now may be reunited with the owners who … [+3586 chars]'},
#   {'source': {'id': None, 'name': 'DIYphotography'},
#    'author': 'Dunja Djudjic',
#    'title': 'These are photos and videos of April 2024 solar eclipse from space',
#    'description': 'On April 8, folks in the US, Canada, and Mexico watched in awe as the Moon danced between the Sun and Earth. While countless stunning...\nThe post These are photos and videos of April 2024 solar eclipse from space appeared first on DIY Photography.',
#    'url': 'https://www.diyphotography.net/these-are-photos-and-videos-of-april-2024-solar-eclipse-from-space/',
#    'urlToImage': 'https://www.diyphotography.net/wp-content/uploads/2024/04/april-8-eclipse-scaled.jpg',
#    'publishedAt': '2024-04-10T16:25:20Z',
#    'content': 'On April 8, folks in the US, Canada, and Mexico watched in awe as the Moon danced between the Sun and Earth. While countless stunning images captured the darkness descending on land, a whole other sp… [+1945 chars]'},
#   {'source': {'id': None, 'name': 'Eclipse.org'},
#    'author': 'thomas.froment@xxxxxxx (Thomas Froment)',
#    'title': 'Re: [eclipse-dev] Opportunity for funded work - Onboarding new contributors and growing the base of committers in the Eclipse IDE related projects',
#    'description': 'Re: [eclipse-dev] Opportunity for funded work - Onboarding new contributors and growing the base of committers in the Eclipse IDE related projects',
#    'url': 'https://www.eclipse.org/lists/eclipse-dev/msg12257.html',
#    'urlToImage': None,
#    'publishedAt': '2024-04-10T16:20:41Z',
#    'content': 'Hi,\r\nThe Eclipse IDE Working Group would like to fund a consultant to help grow the base of contributors and committers on the Eclipse IDE related projects. You will work in support of the Eclipse ID… [+3977 chars]'},
#   {'source': {'id': None, 'name': 'Ig.com.br'},
#    'author': 'Canaltech, Canaltech',
#    'title': 'Destaque da NASA: planetas e eclipse solar são foto astronômica do dia',
#    'description': 'A foto destacada pela NASA hoje traz outro clique do eclipse solar total ocorrido na segunda (8), que mostra Vênus e Júpiter visíveis durante o fenômeno',
#    'url': 'https://tecnologia.ig.com.br/parceiros/canaltech/2024-04-10/destaque-da-nasa--planetas-e-eclipse-solar-sao-foto-astronomica-do-dia.html',
#    'urlToImage': 'https://i0.statig.com.br/bancodeimagens/9w/ph/bj/9wphbjs8n1qd0ya4a6czpp8zn.jpg',
#    'publishedAt': '2024-04-10T16:20:21Z',
#    'content': 'O eclipse solar desta semana apareceu outra vez nas fotos destacadas pela NASA\r\nno site Astronomy Picture of the Day\r\n. A imagem publicada nesta quarta-feira (10) foi capturada por Stephane Vetter em… [+2205 chars]'},
#   {'source': {'id': None, 'name': 'Knowyourmeme.com'},
#    'author': 'sakshi',
#    'title': 'Tiffany Haddish "But The Parasites In Me Want The Candy"',
#    'description': 'Tiffany Haddish "But The Parasites In Me Want The Candy" refers to a catchphrase from the American comedian and actress that went viral on TikTok in April 2024. Haddish participated in the press junket for the 2023 film Haunted Mansion, and in an interview wi…',
#    'url': 'https://knowyourmeme.com/memes/tiffany-haddish-but-the-parasites-in-me-want-the-candy',
#    'urlToImage': 'https://i.kym-cdn.com/entries/icons/original/000/049/282/parasites.jpg',
#    'publishedAt': '2024-04-10T16:18:27Z',
#    'content': 'About\r\nTiffany Haddish "But The Parasites In Me Want The Candy" refers to a catchphrase from the American comedian and actress that went viral on TikTok in April 2024. Haddish participated in the pre… [+2821 chars]'},
#   {'source': {'id': None, 'name': 'Knowyourmeme.com'},
#    'author': 'sakshi',
#    'title': 'Tiffany Haddish Saying "But The Parasites In Me Want The Candy"',
#    'description': 'Tiffany Haddish Saying "But The Parasites In Me Want The Candy" refers to a catchphrase from the American comedian that went viral on TikTok in April 2024. Haddish participated in the press junket for the 2023 film Haunted Mansion, and in an interview with IG…',
#    'url': 'https://knowyourmeme.com/memes/tiffany-haddish-saying-but-the-parasites-in-me-want-the-candy',
#    'urlToImage': 'https://i.kym-cdn.com/entries/icons/original/000/049/282/parasites.jpg',
#    'publishedAt': '2024-04-10T16:18:27Z',
#    'content': 'About\r\nTiffany Haddish Saying "But The Parasites In Me Want The Candy" refers to a catchphrase from the American comedian that went viral on TikTok in April 2024. Haddish participated in the press ju… [+2745 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'feedfeeder',
#    'title': 'Optometrist discusses symptoms of eclipse-related eye damage - FOX 59 Indianapolis',
#    'description': "Optometrist discusses symptoms of eclipse-related eye damageFOX 59 Indianapolis Do your eyes hurt after the eclipse? Here's why they may be irritated and what to do.Yahoo Life Solar eclipse glasses sold through Amazon, Illinois grocery stores recalled, Illino…",
#    'url': 'https://slashdot.org/firehose.pl?op=view&amp;id=173488166',
#    'urlToImage': None,
#    'publishedAt': '2024-04-10T16:14:25Z',
#    'content': 'Sign up for the Slashdot newsletter! OR check out the new Slashdot job board to browse remote jobs or jobs in your areaDo you develop on GitHub? You can keep using GitHub but automatically sync your … [+268 chars]'},
#   {'source': {'id': None, 'name': 'TechSpot'},
#    'author': 'Shawn Knight',
#    'title': 'Digital exodus: Significant dip in Internet traffic observed during eclipse',
#    'description': 'Across Arkansas, Indiana, Ohio, Maine, New Hampshire, and Vermont, which were in the path of totality, Internet traffic dipped between 40 percent to 60 percent during the eclipse, according to Cloudflare.Read Entire Article',
#    'url': 'https://www.techspot.com/news/102572-digital-exodus-significant-dip-internet-traffic-observed-during.html',
#    'urlToImage': 'https://www.techspot.com/images2/news/bigimage/2024/04/2024-04-10-image-19.jpg',
#    'publishedAt': '2024-04-10T16:11:00Z',
#    'content': 'In a nutshell: Eclipse mania has come and gone, but its impact on the populace is still being analyzed. The celestial event captivated millions as it traversed parts of Mexico, the US, and Canada, an… [+1824 chars]'},
#   {'source': {'id': None, 'name': 'Eclipse.org'},
#    'author': 'jonah@xxxxxxx (Jonah Graham)',
#    'title': 'Re: [cdt-dev] CDT Monthly call',
#    'description': 'Re: [cdt-dev] CDT Monthly call',
#    'url': 'https://www.eclipse.org/lists/cdt-dev/msg35525.html',
#    'urlToImage': None,
#    'publishedAt': '2024-04-10T16:06:19Z',
#    'content': 'Copyright © Eclipse Foundation, Inc. All Rights Reserved.'},
#   {'source': {'id': None, 'name': 'Sky.com'},
#    'author': 'Mickey Carroll, science and technology reporter',
#    'title': "It's official - the more you hug, the better your health",
#    'description': 'Hugs, kisses and massages improve your health, according to a new study.',
#    'url': 'https://news.sky.com/story/hugs-kisses-and-massages-are-good-for-your-health-says-research-and-the-more-you-do-them-the-better-13112331',
#    'urlToImage': 'https://e3.365dm.com/24/04/1600x900/skynews-hug-touch_6517113.jpg?20240410164017',
#    'publishedAt': '2024-04-10T16:00:00Z',
#    'content': 'Hugs, kisses and massages improve your health, according to a new study.\r\nResearchers have found consensual positive touch reduces pain, tiredness and blood pressure and can help sleep and respirator… [+2006 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Kathy Miller Perkins, Contributor, \n Kathy Miller Perkins, Contributor\n https://www.forbes.com/sites/kathymillerperkins/',
#    'title': 'Craft A Vision That Unites: Leadership Lessons From The Eclipse',
#    'description': 'Like an eclipse, an inspiring vision can generate anticipation, evoke awe and wonder, create unity, and promote collective experiences.',
#    'url': 'https://www.forbes.com/sites/kathymillerperkins/2024/04/10/craft-a-vision-that-unites-leadership-lessons-from-the-eclipse/',
#    'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/6615a15fca3881ac97f729f3/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#    'publishedAt': '2024-04-10T16:00:00Z',
#    'content': 'Total Solar Eclipse 2024 \r\nAFP via Getty Images\r\nThis week, countless individuals stood under the open sky, the air buzzing with anticipation as the sun and moon aligned for a solar eclipse. This rar… [+5732 chars]'},
#   {'source': {'id': None, 'name': 'Grub Street'},
#    'author': 'By Matthew Schneier',
#    'title': 'Manischewitz Gets a Makeover',
#    'description': 'Manischewitz or Mani’z? The biggest name in matzo is giving itself a clean, updated look with a design assist from the marketers behind Dunkin’ and Burger King.',
#    'url': 'http://www.grubstreet.com/article/manischewitz-debuts-new-design-ahead-of-passover.html',
#    'urlToImage': 'https://pyxis.nymag.com/v1/imgs/5e5/11a/baa786510464afa1bfe08328c94868f956-GRUB-manischewitz-03.1x.rsocial.w1200.jpg',
#    'publishedAt': '2024-04-10T15:55:40Z',
#    'content': 'During the New York City earthquake of 2024, I was on the phone with Team Manischewitz when the ground started to shake. It would be ridiculous to assume that this was less tectonic than Talmudic, th… [+4729 chars]'},
#   {'source': {'id': None, 'name': 'STLtoday.com'},
#    'author': 'Staff reports',
#    'title': 'Lance Lynn, Cardinals seek another series win in rubber game vs. Phillies: First Pitch',
#    'description': 'The Cardinals wrap up their homestand with a Wednesday matinee against the Phillies. First pitch is set for 12:15 p.m.',
#    'url': 'https://www.stltoday.com/sports/professional/mlb/cardinals/lance-lynn-cardinals-seek-another-series-win-in-rubber-game-vs-phillies-first-pitch/article_dfa46326-f39f-11ee-a5bc-1733d4994f9a.html',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/d/fa/dfa46326-f39f-11ee-a5bc-1733d4994f9a/66161a97c7726.preview.jpg?crop=1665%2C874%2C0%2C184&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2024-04-10T15:45:00Z',
#    'content': 'The Cardinals wrap up their homestand with a Wednesday matinee against the Phillies. First pitch is set for 12:15 p.m.\r\nThe two teams have split the first two games of the series, with the Cardinals … [+6755 chars]'},
#   {'source': {'id': None, 'name': 'Atlas Obscura'},
#    'author': 'Danielle Hallock',
#    'title': 'A Perfect Eclipse Takes Center Stage at Atlas Obscura’s Ecliptic Festival',
#    'description': 'Our Hot Springs eclipse hub transformed into a magical celebration of music, art, science, and the cosmos. See for yourself. As storms rolled across the United States on April 8, cities along the path of the 2024 solar eclipse started growing anxious. Texas: …',
#    'url': 'https://www.atlasobscura.com/articles/2024-eclipse-festival-photos',
#    'urlToImage': 'https://img.atlasobscura.com/4uXWR687o_iscfkL3KDpP5U6AdaVEUkPEIInP0JFG5Y/rt:fit/w:600/q:81/sm:1/scp:1/ar:1/aHR0cHM6Ly9hdGxh/cy1kZXYuczMuYW1h/em9uYXdzLmNvbS91/cGxvYWRzL2Fzc2V0/cy8xNDQ3MGMxMC0z/MDg2LTQxZTktYTU4/Ni1kMWZmMzQxZTlk/MDFjNmEwMDcxZDQ2/OWVlNjdkOWNfSmVy/ZW15Um9kZ2VyczUu/anBn.jpg',
#    'publishedAt': '2024-04-10T15:45:00Z',
#    'content': 'As storms rolled across the United States on April 8, cities along the path of the 2024 solar eclipse started growing anxious. Texas: cloudy. Pennsylvania and New York: rain. Arkansas: Will it or won… [+3574 chars]'},
#   {'source': {'id': None, 'name': 'TheStranger.com'},
#    'author': 'Rich Smith',
#    'title': "Slog AM: Gun Sales Down in WA, Another Boeing Whistleblower Emerges, Poll Shows the Message on More Housing Isn't Working",
#    'description': 'The Stranger\'s morning news roundup.\n \n by Rich Smith\n \n \n \n They\'re not getting the message: In a recent poll, only 26% of Washington voters agreed that "building more units of housing in my community will help stabilize the price of housing where I live," a…',
#    'url': 'https://www.thestranger.com/slog-am/2024/04/10/79461749/slog-am-gun-sales-down-in-wa-another-boeing-whistleblower-emerges-poll-shows-the-message-on-more-housing-isnt-working',
#    'urlToImage': 'https://media1.fdncms.com/stranger/imager/u/large/79462637/gettyimages-1358308239.jpg',
#    'publishedAt': '2024-04-10T15:35:00Z',
#    'content': 'They\'re not getting the message: In a recent poll, only 26% of Washington voters agreed that "building more units of housing in my community will help stabilize the price of housing where I live," ac… [+6662 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'newsweek.com',
#    'title': 'Hundreds of Tesla owners flood charging station',
#    'description': 'The total solar eclipse was a once-in-a-lifetime experience for millions of people, but traveling home from the event quickly turned into a challenge for hundreds of Tesla owners. The moon was positioned for a few minutes on Monday so that the entire view of …',
#    'url': 'https://biztoc.com/x/af726ec441b6cef5',
#    'urlToImage': 'https://c.biztoc.com/p/af726ec441b6cef5/s.webp',
#    'publishedAt': '2024-04-10T15:30:05Z',
#    'content': 'The total solar eclipse was a once-in-a-lifetime experience for millions of people, but traveling home from the event quickly turned into a challenge for hundreds of Tesla owners.The moon was positio… [+278 chars]'},
#   {'source': {'id': None, 'name': 'Aristeguinoticias.com'},
#    'author': 'Redacción AN / APV',
#    'title': 'Embajador de Reino Unido en México toca y baila banda en playa de Mazatlán | Video',
#    'description': 'El pasado 28 de marzo, cientos de músicos salieron a las calles de la ciudad sinaloense para protestar contra los hoteleros que buscan prohibir a estas bandas en las playas.',
#    'url': 'https://aristeguinoticias.com/1004/mexico/embajador-de-reino-unido-en-mexico-toca-y-baila-banda-en-playa-de-mazatlan-video/',
#    'urlToImage': 'https://editorial.aristeguinoticias.com/wp-content/uploads/2024/04/embajador-reino-unido-banda-mazatlan-10042024.jpg',
#    'publishedAt': '2024-04-10T15:28:23Z',
#    'content': 'Jon Benjamin, embajador del Reino Unido en México, se proclamó a favor de la banda sinaloense, y en su visita a Mazatlán para observar el eclipse total del pasado 8 de abril, aprovechó para pasar un … [+2044 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'George Dvorsky',
#    'title': 'Move Over Eclipse, a New Celestial Wonder Is Set to Take Center Stage',
#    'description': 'T Coronae Borealis, a binary star system located 3,000 light-years from Earth, is a ticking time bomb waiting to explode. And if the recurring nova follows its usual pattern, we can expect to see a new, albeit temporary, star appearing in our night sky any da…',
#    'url': 'https://gizmodo.com/move-over-eclipse-a-new-celestial-wonder-is-set-to-tak-1851399742',
#    'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/ee9645d07573d1c570c2d12eb22a73cb.gif',
#    'publishedAt': '2024-04-10T15:25:00Z',
#    'content': 'T Coronae Borealis, a binary star system located 3,000 light-years from Earth, is a ticking time bomb waiting to explode. And if the recurring nova follows its usual pattern, we can expect to see a n… [+3847 chars]'}]}
